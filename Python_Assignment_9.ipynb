# %%
1. To what does a relative path refer?
A. relative path refers to the target path from the current directory.

2. What does an absolute path start with your operating system?
A. An absolute path is defined as specifying the location of a file or directory from the root directory(/).

3. What do the functions os.getcwd() and os.chdir() do?
A. os.getcwd() gives the current working directory path,os.chdir() is used to change the current working directory.

4. What are the . and .. folders?
A. . means current folder,where '..' refers to preceding folder.

5. In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?
A.

# %%
path='C:/bacon/eggs/spam.txt'
import os
print('basename:'+ os.path.basename(path))
print('directory nme:'+os.path.dirname(path))
# Out:
# basename:spam.txt
# directory nme:C:/bacon/eggs

# %%
6. What are the three “mode” arguments that can be passed to the open() function?
A. 'r','a','w'--> read,append,write modes can be passed to open() function.

7. What happens if an existing file is opened in write mode?
A. The input will override the present content in the file.

8. How do you tell the difference between read() and readlines()?
A. read() : Reads the size bytes from the current position of the file
   readlines(): Read the entire file and save it in a list with each line in the file as an element in the list.
9. What data structure does a shelf value resemble?
A. Dictionary data structure.
